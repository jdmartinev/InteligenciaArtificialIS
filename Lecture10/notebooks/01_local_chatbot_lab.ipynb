# %% [markdown]
# # Introducción a los LLMs Locales con Ollama
#
# ¡Es hora de ponerse prácticos!
#
# Este notebook demuestra cómo ejecutar un Modelo de Lenguaje Grande (LLM) de forma local usando Ollama y LangChain. Todo correrá directamente en tu computador.
#
# Ollama nos permite ejecutar LLMs localmente en nuestra máquina. LangChain es un SDK (biblioteca de código reutilizable) que facilita la interacción con LLMs.
#
# ## 1. Prerrequisitos
#
# Antes de ejecutar este notebook, necesitas instalar Ollama y descargar un modelo. Sigue los pasos a continuación.
#
# ### 1.1 Instalación de Ollama
#
# **macOS:**
# - Descarga el instalador desde [ollama.ai](https://ollama.ai)
# - Abre el archivo descargado y sigue las instrucciones de instalación
#
# **Windows:**
# - Descarga el instalador desde [ollama.ai](https://ollama.ai)
# - Ejecuta el instalador y sigue las instrucciones
#
# **Linux:**

# %%
 # %%bash
curl -fsSL https://ollama.ai/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to render group...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# >>> Enabling and starting ollama service...
# Created symlink /etc/systemd/system/default.target.wants/ollama.service → /etc/systemd/system/ollama.service.
# >>> NVIDIA GPU installed.

# %% [markdown]
# Verifica tu instalación (Windows, Mac y Linux):

# %%
# %%bash
# ollama --version
# Out:
# ollama version is 0.20.6

# %% [markdown]
# ### 1.2 Descarga del Modelo TinyLlama
#
# Descarga el modelo TinyLlama (aproximadamente 600MB). Existe un amplio catálogo de modelos disponibles en Ollama, incluyendo DeepSeek y otros, pero TinyLlama es el más pequeño, lo cual es ideal para propósitos de demostración:
# """

# %%
# %%bash
# ollama pull tinyllama:1.1b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest
# pulling 2af3b81862c6:   0% ▕                  ▏ 2.4 MB/637 MB                  pulling manifest
# pulling 2af3b81862c6:   2% ▕                  ▏  12 MB/637 MB                  pulling manifest
# pulling 2af3b81862c6:   3% ▕                  ▏  19 MB/637 MB                  pulling manifest
# pulling 2af3b81862c6:   5% ▕                  ▏  30 MB/637 MB                  pulling manifest
# pulling 2af3b81862c6:   7% ▕█                 ▏  46 MB/637 MB                  pulling manifest
# pulling 2af3b81862c6:   8% ▕█                 ▏  53 MB/637 MB                  pulling manifest
# pulling 2af3b81862c6:  11% ▕██                ▏  73 MB/637 MB                  pulling manifest
# pulling 2af3b81862c6:  20% ▕███               ▏ 127 MB/637 MB                  pulling manifest
# pulling 2af3b81862c6:  25% ▕████              ▏ 157 MB/637 MB                  pulling manifest
# pulling 2af3b81862c6:  33% ▕█████             ▏ 209 MB/637 MB                  pulling manifest
# pulling 2af3b81862c6:  40% ▕███████           ▏ 252 MB/637 MB  231 MB/s      1spulling manifest
# pulling 2af3b81862c6:  44% ▕███████           ▏ 280 MB/637 MB  231 MB/s      1spulling manifest
# pulling 2af3b81862c6:  52% ▕█████████         ▏ 334 MB/637 MB  231 MB/s      1spulling manifest
# pulling 2af3b81862c6:  62% ▕███████████       ▏ 392 MB/637 MB  231 MB/s      1spulling manifest
# pulling 2af3b81862c6:  64% ▕███████████       ▏ 410 MB/637 MB  231 MB/s      0spulling manifest
# pulling 2af3b81862c6:  72% ▕████████████      ▏ 460 MB/637 MB  231 MB/s      0spulling manifest
# pulling 2af3b81862c6:  78% ▕██████████████    ▏ 499 MB/637 MB  231 MB/s      0spulling manifest
# pulling 2af3b81862c6:  81% ▕██████████████    ▏ 516 MB/637 MB  231 MB/s      0spulling manifest
# pulling 2af3b81862c6:  85% ▕███████████████   ▏ 543 MB/637 MB  231 MB/s      0spulling manifest
# pulling 2af3b81862c6:  87% ▕███████████████   ▏ 556 MB/637 MB  231 MB/s      0spulling manifest
# pulling 2af3b81862c6:  88% ▕███████████████   ▏ 558 MB/637 MB  279 MB/s      0spulling manifest
# pulling 2af3b81862c6:  89% ▕████████████████  ▏ 568 MB/637 MB  279 MB/s      0spulling manifest
# pulling 2af3b81862c6:  91% ▕████████████████  ▏ 579 MB/637 MB  279 MB/s      0spulling manifest
# pulling 2af3b81862c6:  92% ▕████████████████  ▏ 586 MB/637 MB  279 MB/s      0spulling manifest
# pulling 2af3b81862c6:  94% ▕████████████████  ▏ 596 MB/637 MB  279 MB/s      0spulling manifest
# pulling 2af3b81862c6:  95% ▕█████████████████ ▏ 605 MB/637 MB  279 MB/s      0spulling manifest
# pulling 2af3b81862c6:  95% ▕█████████████████ ▏ 608 MB/637 MB  279 MB/s      0spulling manifest
# pulling 2af3b81862c6:  97% ▕█████████████████ ▏ 618 MB/637 MB  279 MB/s      0spulling manifest
# pulling 2af3b81862c6:  99% ▕█████████████████ ▏ 634 MB/637 MB  279 MB/s      0spulling manifest
# pulling 2af3b81862c6: 100% ▕█████████████████ ▏ 635 MB/637 MB  279 MB/s      0spulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B                         pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠸ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠼ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠴ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠦ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠧ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠇ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠏ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠋ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠙ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest ⠹ pulling manifest
# pulling 2af3b81862c6: 100% ▕██████████████████▏ 637 MB
# pulling af0ddbdaaa26: 100% ▕██████████████████▏   70 B
# pulling c8472cd9daed: 100% ▕██████████████████▏   31 B
# pulling fa956ab37b8c: 100% ▕██████████████████▏   98 B
# pulling 6331358be52a: 100% ▕██████████████████▏  483 B
# verifying sha256 digest
# writing manifest
# success

# %% [markdown]
# ## 2. Configuración del Entorno Python
#
# Instala los paquetes necesarios. Instalaremos LangChain, una de las bibliotecas más populares para interactuar con LLMs. langchain-ollama nos permite interactuar con modelos localmente.

# %%
# %%bash
# pip install langchain langchain-ollama
# Out:
# Collecting langchain
#   Downloading langchain-1.2.15-py3-none-any.whl.metadata (5.8 kB)
# Collecting langchain-ollama
#   Downloading langchain_ollama-1.1.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Downloading langchain_core-1.2.28-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.5 (from langchain)
#   Downloading langgraph-1.1.6-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from langchain) (2.12.5)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading langsmith-0.7.30-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=23.2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading uuid_utils-0.14.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_sdk-0.3.13-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading ormsgpack-1.12.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: httpx>=0.25.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.32.5)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain)
#   Downloading zstandard-0.25.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.12.1)
# Requirement already satisfied: certifi in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.7)
# Requirement already satisfied: h11>=0.16 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Collecting ollama<1.0.0,>=0.6.1 (from langchain-ollama)
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.5.0)
# Downloading langchain-1.2.15-py3-none-any.whl (112 kB)
# Downloading langchain_core-1.2.28-py3-none-any.whl (508 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.1.6-py3-none-any.whl (169 kB)
# Downloading langgraph_checkpoint-4.0.1-py3-none-any.whl (50 kB)
# Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.13-py3-none-any.whl (96 kB)
# Downloading langsmith-0.7.30-py3-none-any.whl (372 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.14.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (345 kB)
# Downloading langchain_ollama-1.1.0-py3-none-any.whl (31 kB)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Downloading ormsgpack-1.12.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
# Downloading zstandard-0.25.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 126.4 MB/s  0:00:00
# Installing collected packages: zstandard, uuid-utils, tenacity, ormsgpack, jsonpatch, ollama, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langchain-ollama, langgraph-prebuilt, langgraph, langchain
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [langchain]14 [langchain]core]
# Successfully installed jsonpatch-1.33 langchain-1.2.15 langchain-core-1.2.28 langchain-ollama-1.1.0 langgraph-1.1.6 langgraph-checkpoint-4.0.1 langgraph-prebuilt-1.0.9 langgraph-sdk-0.3.13 langsmith-0.7.30 ollama-0.6.1 ormsgpack-1.12.2 tenacity-9.1.4 uuid-utils-0.14.1 zstandard-0.25.0

# %% [markdown]
# ## 3. Usando el LLM con LangChain
#
# El código a continuación nos permite interactuar con el modelo tinyllama alojado localmente en nuestros computadores. Simplemente enviamos el siguiente mensaje al modelo: "I love programming".
#
# Lee los comentarios del código si quieres entender exactamente qué está pasando.

# %%
# Importamos las bibliotecas necesarias
from langchain_ollama import ChatOllama
from langchain_core.messages import AIMessage
 
# Inicializamos el LLM. Aquí elegimos el modelo y la temperatura
# (que controla la aleatoriedad de la salida). llm es lo que usaremos para llamar al modelo.
llm = ChatOllama(
    model="tinyllama:1.1b",
    temperature=0,  # 0 para salidas más deterministas
)
 
# Debemos proveer un arreglo de mensajes al modelo. El primer mensaje es siempre el mensaje
# de sistema, que le indica al modelo cómo comportarse. El segundo es el mensaje del usuario,
# que es lo que queremos preguntarle al modelo.
messages = [
    (
        "system",
        "You are a helpful assistant",
    ),
    ("human", "I love programming."),
]
 
# Enviamos el arreglo de mensajes al modelo y obtenemos la respuesta.
# La respuesta es un objeto AIMessage que contiene el texto generado, que imprimiremos a continuación.
ai_msg = llm.invoke(messages)
 
# Mostramos la respuesta
print(ai_msg.content)
# Out:
# I'm glad to hear that you enjoy programming! Here are some tips and resources to help you get started:
#
# 1. Learn the basics of programming: there are many online tutorials, books, and courses available that can help you learn the fundamentals of programming. Start with basic concepts like variables, functions, loops, and data types. 2. Practice coding: try writing simple programs to get a feel for how code works. You can find plenty of free online resources on websites like codecademy or edx. 3. Join a community: join a local programming group or attend a meetup event in your area. This will help you connect with other programmers and learn from their experiences. 4. Read books and articles: there are many great books and articles available on programming topics, such as "the cathedral and the bazaar" by steve levy and "programming is fun!" by john mccain. 5. Attend conferences: attend conferences or workshops related to your area of interest. This will help you learn from experts in the field and network with other programmers. 6. Build projects: try building small projects, such as a simple web application or game, to get a feel for how code works in practice. Remember that learning programming takes time and patience. Don't be discouraged if you don't see immediate results. With practice and persistence, you'll become a better programmer over time!

# %% [markdown]
# # 4. Probando Diferentes Prompts
#
# Probemos un par de ejemplos para ver qué puede hacer el modelo, cambiando el arreglo de mensajes:

# %%
# Pedimos una explicación
messages = [
    (
        "system",
        "You are a helpful and informative AI assistant.",
    ),
    ("human", "Explain the concept of a neural network in simple terms."),
]
 
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# A neural network is a type of artificial intelligence (AI) system that mimics the way human brains process information. It consists of several layers of interconnected neurons, also known as nodes or units, which receive input data and produce output based on their connections to other nodes. The input data can be either sensory inputs like images or sounds, or symbolic data like text or numerical data.
#
# The neural network's output is determined by the combination of all the neurons' outputs, which are then processed by the next layer of neurons. This process is repeated until a specific output is achieved. The output can be used to make predictions or decisions based on the input data.
#
# Neural networks are trained using a technique called backpropagation, where the network's weights (the connections between nodes) are adjusted based on the output of the network and the input data. This process is repeated until the network converges, which means that it reaches a stable state.
#
# In summary, a neural network is a complex system that mimics the way human brains process information. It consists of several layers of interconnected neurons, each with its own set of connections, and uses backpropagation to adjust the weights based on the output and input data.

# %%
# Pedimos algo de código
messages = [
    (
        "system",
        "You are an expert Python programmer.",
    ),
    ("human", "Write a function to check if a string is a palindrome."),
]
 
ai_msg = llm.invoke(messages)
print(ai_msg.content)
# Out:
# Here's a Python function that checks whether a given string is a palindrome or not:
#
# ```python
# def is_palindrome(string):
#     """
#     Checks whether the given string is a palindrome (reversed) or not.
#
#     Args:
#         string (str): The string to check for palindromicness.
#
#     Returns:
#         bool: True if the string is a palindrome, False otherwise.
#     """
#     # Convert the string to lowercase and remove any leading or trailing spaces
#     string = string.lower().strip()
#
#     # Check if the string is empty or contains only whitespace characters
#     if not string:
#         return True
#
#     # Reverse the string and check if it's equal to the original string
#     reversed_string = string[::-1]
#     if string == reversed_string:
#         return True
#     else:
#         return False
# ```
#
# Here's an example usage:
#
# ```python
# >>> is_palindrome("race a car")
# True
# >>> is_palindrome("race a car")
# False
# ```

# %% [markdown]
# ## 5. Creando un Chatbot Básico
#
# Vamos a crear una interfaz de chat simple para interactuar con el modelo. Cada celda representará una interacción. Sigue los pasos a continuación; tendrán más sentido a medida que los vayas ejecutando.
# """

# %%
# Configuración: ejecuta esta celda primero
from langchain_ollama import ChatOllama

# %%
# Inicializamos el LLM
llm = ChatOllama(
    model="tinyllama:1.1b",
    temperature=0
)
 
# Prompt de sistema: define el comportamiento del asistente
system_prompt = "You are a helpful assistant"
 
print("-" * 30)
# Out:
# ------------------------------

# %% [markdown]
# Creemos una celda para nuestra primera interacción, diciéndole al modelo cuál es nuestro color favorito. Ten en cuenta que la respuesta puede ser extraña, ya que no estamos usando el mejor modelo disponible. Pero debería indicar que entendió que tu color favorito es el azul."""

# %%
# Primera interacción
user_message = "My favorite color is blue."
 
# Creamos mensajes nuevos solo para esta interacción (sin historial previo)
messages = [
    ("system", system_prompt),
    ("human", user_message)
]
 
# Obtenemos la respuesta
ai_msg = llm.invoke(messages)
 
print(f"Tú: {user_message}")
print(f"Asistente: {ai_msg.content}")
# Out:
# Tú: My favorite color is blue.
# Asistente: I do not have the ability to feel emotions or preferences like humans do. However, based on your statement that you enjoy wearing blue clothing, I can say that blue is a popular and versatile color that can be worn in various ways. It's often associated with nature, calmness, and serenity, making it a great choice for those who prefer a calming and relaxing atmosphere. In terms of fashion, blue can be paired with different colors to create a unique and eye-catching look. Whether you choose to wear it as a base color or add accents like stripes, polka dots, or prints, blue is sure to make a statement.

# %% [markdown]
# Ahora hagamos una pregunta de seguimiento:

# %%
# Segunda interacción
user_message = "What's my favorite color?"
 
# Creamos mensajes nuevos solo para esta interacción (sin historial previo)
messages = [
    ("system", system_prompt),
    ("human", user_message)
]
 
# Obtenemos la respuesta
ai_msg = llm.invoke(messages)
 
print(f"Tú: {user_message}")
print(f"Asistente: {ai_msg.content}")
# Out:
# Tú: What's my favorite color?
# Asistente: I do not have the ability to have feelings or preferences like humans. However, based on your previous responses, you may be interested in learning about some popular colors and their meanings:
#
# 1. Blue - symbolizes trust, loyalty, and peacefulness. It is often associated with water, sky, and the ocean.
#
# 2. Green - represents growth, new beginnings, and nature's cycles. It is often associated with earth, soil, and the vegetation.
#
# 3. Red - symbolizes passion, energy, and love. It is often associated with fire, blood, and the heart.
#
# 4. Yellow - symbolizes happiness, optimism, and sunshine. It is often associated with gold, light, and warmth.
#
# 5. Purple - represents royalty, mystery, and power. It is often associated with royal blue, violet, and deep purple.
#
# 6. White - symbolizes purity, innocence, and peacefulness. It is often associated with snow, ice, and the white color.
#
# 7. Black - symbolizes darkness, mystery, and power. It is often associated with shadow, night, and the black color.
#
# 8. Gold - symbolizes wealth, prosperity, and abundance. It is often associated with gold, yellow, and warmth.
#
# 9. Orange - symbolizes energy, vitality, and excitement. It is often associated with orange, sun, and warmth.
#
# 10. Pink - symbolizes love, beauty, and femininity. It is often associated with pink, rose, and softness.

# %% [markdown]
# Como puedes ver, ¡el modelo no recuerda nuestro color favorito! Podrías preguntarte por qué. Seguramente herramientas como ChatGPT pueden recordar el contexto completo de la conversación. Este es el concepto de memoria. El LLM, por sí solo, no recuerda conversaciones pasadas. Necesitamos diseñar nuestra aplicación para que lo haga.
#
# Exploremos cómo hacerlo a continuación, y cómo herramientas como ChatGPT lo gestionan.

# %% [markdown]
# ## 6. Entendiendo Cómo Funciona la Memoria de Conversación
#
# La forma más sencilla de gestionar esto es pasar todo el historial de conversación al modelo, en lugar de solo el mensaje individual:

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import SystemMessage, HumanMessage
 
# Inicializamos el LLM como antes
llm = ChatOllama(
    model="tinyllama:1.1b",
    temperature=0
)
 
# Definimos el historial de conversación (siempre empieza con un prompt de sistema).
# conversation es una lista de mensajes. SystemMessage representa un mensaje de sistema
# y acepta el contenido como parámetro.
conversation = [SystemMessage(content="You are a helpful assistant")]
 
# Definimos una función llamada chat que toma la entrada del usuario como parámetro.
# Esta función se usará para interactuar con el modelo.
def chat(user_input: str):
    # 1) Agregamos el mensaje del usuario al historial.
    # Ahora la lista contiene el mensaje de sistema y el mensaje del usuario.
    conversation.append(HumanMessage(content=user_input))
 
    # 2) Llamamos al modelo con la lista completa de conversación
    ai_msg = llm.invoke(conversation)
 
    # 3) Mostramos el intercambio
    print(f"Tú: {user_input}")
    print(f"Asistente: {ai_msg.content}")
    print(f"[Longitud de conversación: {len(conversation) + 1} mensajes]")  # +1 por la respuesta del modelo
 
    # 4) Agregamos la respuesta del modelo al historial. Ahora la lista contiene el mensaje
    # de sistema, el mensaje del usuario y la respuesta del modelo, que se usará en la próxima interacción.
    conversation.append(ai_msg)
 
    return ai_msg.content
 
print("Chat Con Memoria")
print("-" * 30)
# Out:
# Chat Con Memoria
# ------------------------------

# %%
"""Démosle nuevamente nuestro color favorito:"""
 
# Primera interacción: compartimos el color favorito
chat("My favorite color is blue")
# Out:
# Tú: My favorite color is blue
# Asistente: I do not have the ability to feel emotions or preferences like humans. However, based on your description of your favorite color, it seems that you enjoy the calming and soothing qualities of blue. This could include its deep blue hue, which is often associated with peacefulness and tranquility, as well as its cooler tones, which can help to reduce stress and promote relaxation. Additionally, blue may evoke feelings of nostalgia or remembrance, as it has been used in art and design for centuries to represent the sky, water, and other natural elements. Overall, blue is a color that can bring a sense of calmness and serenity to your life, making it an excellent choice for someone who enjoys a calming and peaceful environment.
# [Longitud de conversación: 3 mensajes]
# 'I do not have the ability to feel emotions or preferences like humans. However, based on your description of your favorite color, it seems that you enjoy the calming and soothing qualities of blue. This could include its deep blue hue, which is often associated with peacefulness and tranquility, as well as its cooler tones, which can help to reduce stress and promote relaxation. Additionally, blue may evoke feelings of nostalgia or remembrance, as it has been used in art and design for centuries to represent the sky, water, and other natural elements. Overall, blue is a color that can bring a sense of calmness and serenity to your life, making it an excellent choice for someone who enjoys a calming and peaceful environment.'

# %%
"""Ahora veamos si lo recuerda:"""
 
# Segunda interacción: ponemos a prueba la memoria
chat("What's my favorite color?")
# Out:
# Tú: What's my favorite color?
# Asistente: I do not have the ability to feel emotions or preference like humans. However, based on your description of your favorite color, it seems that you enjoy the calming and soothing qualities of blue. This could include its deep blue hue, which is often associated with peacefulness and tranquility, as well as its cooler tone, which can help to reduce stress and promote relaxation. Additionally, blue may evoke feelings of nostalgia or remembrance, as it has been used in art and design for centuries to represent the sky, water, and other natural elements. Overall, blue is a color that can bring a sense of calmness and serenity to your life, making it an excellent choice for someone who enjoys a calming and peaceful environment.
# [Longitud de conversación: 5 mensajes]
# 'I do not have the ability to feel emotions or preference like humans. However, based on your description of your favorite color, it seems that you enjoy the calming and soothing qualities of blue. This could include its deep blue hue, which is often associated with peacefulness and tranquility, as well as its cooler tone, which can help to reduce stress and promote relaxation. Additionally, blue may evoke feelings of nostalgia or remembrance, as it has been used in art and design for centuries to represent the sky, water, and other natural elements. Overall, blue is a color that can bring a sense of calmness and serenity to your life, making it an excellent choice for someone who enjoys a calming and peaceful environment.'

# %% [markdown]
# ¡Ahora el modelo debería recordar correctamente tu color favorito! Esto se debe a que estamos llevando el registro del historial de conversación.

# %% [markdown]
# ## 7. El Desafío de la Ventana de Contexto
#
# Aunque nuestra solución de memoria simple funciona inicialmente (porque pasamos todo el historial como entrada), tiene una limitación crítica: **la ventana de contexto**.
#
# ### Entendiendo la Ventana de Contexto
#
# Cada modelo de lenguaje tiene una "ventana de contexto" fija: el número máximo de tokens (aproximadamente palabras o fragmentos de palabras) que puede procesar a la vez:
#
# - **TinyLlama**: ~2,048 tokens (aproximadamente 1,500 palabras)
# - **GPT-3.5**: ~4,096 tokens
# - **GPT-4**: entre 8,192 y 128,000 tokens según la versión
# - **Claude 3**: hasta 200,000 tokens
#
# A medida que la conversación crece, eventualmente alcanzamos este límite. Cuando eso ocurre:
#
# 1. El modelo no puede ver mensajes más allá del tamaño de la ventana
# 2. Efectivamente "olvida" las partes más antiguas de la conversación
# 3. El procesamiento se vuelve más lento con contextos más grandes
# 4. Puedes recibir errores si superas la ventana de contexto
#
# ## 8. Soluciones al Problema de la Ventana de Contexto
#
# En sistemas de producción como ChatGPT, varias técnicas abordan esta limitación:
#
# ### 1. Ventana de Contexto Deslizante
# Este enfoque conserva solo los N mensajes más recientes, más el prompt de sistema.
#
# **Ejemplo:** Si limitas a 10 mensajes y la conversación llega a 15, descartarías los 5 mensajes más antiguos (excepto el prompt de sistema).
#
# Es como tener una conversación donde solo recuerdas lo dicho en los últimos minutos. Es simple, pero pierde toda la información anterior.
#
# ### 2. Resumen de Conversación (Summarization)
# Esta técnica condensa las partes más antiguas de la conversación en resúmenes para ahorrar tokens.
#
# **Ejemplo:** Después de 10 intercambios, el sistema podría reemplazar esos 20 mensajes con un único resumen: "El usuario preguntó sobre redes neuronales. El asistente las explicó y proporcionó un ejemplo en Python para detectar palíndromos."
#
# Esto preserva los puntos clave mientras reduce significativamente el uso de tokens.
#
# ### 3. Gestión de Sesiones con Base de Datos
#
# Este enfoque usa una base de datos para almacenar historiales completos de conversación asociados a sesiones únicas de usuario. Así funciona:
#
# 1. **Creación de sesión**: Cuando un usuario comienza a chatear, el sistema crea un ID de sesión único (como "session_abc123")
#
# 2. **Almacenamiento de mensajes**: Cada mensaje del usuario y del modelo se guarda en una tabla de la base de datos vinculada a ese ID de sesión
#
# 3. **Gestión de la ventana de contexto**: Al preparar el prompt para el LLM, el sistema:
#    - Recupera todos los mensajes de la sesión
#    - Aplica estrategias para ajustarse a la ventana de contexto (ventana deslizante o resumen)
#    - Envía la conversación optimizada al modelo
#    - Almacena la nueva respuesta de vuelta en la base de datos
#
# **Ejemplo práctico:**
# - Un usuario ha estado chateando durante horas con ChatGPT
# - Su sesión "user_789" ahora tiene 200 mensajes en la base de datos
# - Cuando envía el mensaje #201, el sistema:
#   - Recupera los 200 mensajes anteriores de la base de datos
#   - Selecciona los más relevantes para ajustarse a la ventana de contexto
#   - Obtiene una respuesta del modelo
#   - Agrega el mensaje #201 y la respuesta a la base de datos
#   - Aunque el modelo solo "ve" la porción reciente, el historial completo permanece en la base de datos
#
# Así es como servicios como ChatGPT pueden mantener "memoria" en conversaciones muy largas, incluso cuando cierras el navegador y vuelves más tarde.
#
# ## ¿Qué usa ChatGPT típicamente?
#
# ChatGPT usa un enfoque híbrido que combina varias de estas técnicas:
#
# 1. **Técnica principal:** Usa una ventana de contexto muy grande (hasta 128K tokens en GPT-4o) y gestión de sesiones con base de datos, lo que le permite "recordar" conversaciones notablemente largas.
#
# 2. **Para conversaciones largas:** Cuando las conversaciones superan estos límites, emplea técnicas de ventana deslizante que priorizan:
#    - El prompt de sistema e instrucciones
#    - Los mensajes más recientes
#    - Mensajes con alta densidad de información
#    - Mensajes referenciados explícitamente por el usuario
#
# 3. **Compresión dinámica:** En algunas versiones, ChatGPT emplea algoritmos de compresión dinámica que resumen o eliminan selectivamente partes de la conversación menos relevantes para el intercambio actual.
#
# Aunque estas soluciones ayudan, sigue existiendo un límite absoluto de lo que cualquier modelo puede "recordar" en una sola conversación. Por eso, incluso ChatGPT a veces "olvida" cosas mencionadas mucho antes en conversaciones muy largas.
#
# ## 9. Ventajas de los LLMs Locales
#
# Usar LLMs locales con herramientas como Ollama tiene varias ventajas:
#
# 1. **Privacidad**: Tus datos nunca salen de tu computador
# 2. **Sin costos de API**: Ejecuta el modelo tanto como quieras sin pagar por consulta
# 3. **Uso sin conexión**: No necesitas internet una vez que el modelo está descargado
# 4. **Sin límites de uso**: Ejecuta tantas consultas como tu hardware pueda manejar
#
# ## 10. Recursos para Seguir Aprendiendo
#
# - [Documentación de Ollama](https://github.com/ollama/ollama/blob/main/README.md)
# - [Documentación de LangChain](https://python.langchain.com/docs/get_started/introduction)
# - [Información sobre TinyLlama](https://github.com/jzhang38/TinyLlama)
# """
